# %% [markdown]
# # Sentiment Analysis for WittyWicky Inc.

# %% [markdown]
# ## Introduction

# %% [markdown]
# WittyWicky Inc. is a consulting firm that designs brand strategy for a lot of product startups. Their modus operandi is to gain the pulse of competing products and the associated sentiment from social media. Social media has profound impact in capturing the potential customers and thus there are a lot of consulting firms that operate in the digital strategy space. Whether it is to design a marketing campaign or look at the effect of marketing campaigns on user engagement or sentiment, it is a very valuable tool.
#
# Manual assessment of sentiment is very time consuming and automatic sentiment analysis would deliver a lot of value. As a team of data scientists consulting for WittyWicky Inc., you are now responsible for meeting their business outcomes.
#
# #### Problem Statement
# Twitter has now become a useful way to build one's business as it helps in giving the brand a voice and a personality. The platform is also a quick, easy and inexpensive way to gain valuable insight from the desired audience. Identifying the sentiments about the product/brand can help the business take better actions.
#
# You have with you evaluated tweets about multiple brands. The evaluators(random audience) were asked if the tweet expressed positive, negative, or no emotion towards a product/brand and labelled accordingly.
#
# ### Dataset Description
# This dataset contains around 7k tweet text with the sentiment label.
#
# The file train.csv has 3 columns
#
# tweet_id - Unique id for tweets. tweet - Tweet about the brand/product sentiment - 0: Negative, 1: Neutral, 2: Positive, 3: Can't Tell
#
# #### Evaluation Metric
# We will be using ‘weighted’ F1-measure as the evaluation metric for this competition. For more information on the F1-metric refer to https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
#
# #### Submission format
# Submission file should have two columns, one for tweet_id and sencond for sentiment [0: Negative, 1: Neutral, 2: Positive, 3: Can't Tell]. A sample submission file has also been attached for reference.

# %% [markdown]
# #### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from wordcloud import WordCloud, STOPWORDS
#Display all the columns 
pd.set_option('display.max_columns',None)
# Display full length the column
pd.set_option('display.max_colwidth', -1)

# %%
import re
from nltk.corpus import stopwords
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from string import punctuation
from nltk.stem.porter import *
from gensim.models import Word2Vec,KeyedVectors
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from spellchecker import SpellChecker
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, SGDClassifier

# %%
# pip install pyspellchecker

# %% [markdown]
# #### Loading Training Data

# %%
df_train = pd.read_csv('../data/raw/train.csv')

# %% [markdown]
# #### Loading Test Data

# %%
df_test = pd.read_csv('../data/raw/test.csv')

# %% [markdown]
# ### Data Analysis

# %%
# Basic exploration of train data to check labels
df_train.tail()
# Out:
#       tweet_id  \
# 7269  3343
# 7270  5334
# 7271  5378
# 7272  2173
# 7273  3162
#
#                                                                                                                                              tweet  \
# 7269  @mention Google plze Tammi.  I'm in middle of #SXSW craziness and everything is soooooo busy!
# 7270  RT @mention ÷¼ Are you all set? ÷_ {link} ÷_ #edchat #musedchat #sxsw #sxswi #newTwitter
# 7271  RT @mention Aha! Found proof of lactation room, excuse me, &quot;Mother's Room,&quot; brought to you by Google, at last year's #SXSW. {link}
# 7272  We just launched our iPad app at #SXSW! Get all the details + the first edition FREE: {link}
# 7273  The next fin serv battle is vs Apple, GOOG, Mobile operators. They have consumer loyalty and tons of cash (vs. Banks) #bankinnovate #SXSW
#
#       sentiment
# 7269  1
# 7270  1
# 7271  1
# 7272  1
# 7273  1

# %%
# Basic exploration of test data to check labels
df_test.tail()
# Out:
#       tweet_id  \
# 1814  1550
# 1815  1933
# 1816  9052
# 1817  4219
# 1818  7210
#
#                                                                                                                             tweet
# 1814  @mention @mention @mention Hmmm....how fast can #apple build a new store in time for #sxsw  {link}
# 1815  Samsung Galaxy S II Appears At FCC And Team Android #SXSW Party {link} via @mention
# 1816  @mention You could buy a new iPad 2 tmrw at the Apple pop-up store at #sxsw: {link}
# 1817  Wow very long queue of people at apple pop up store now, some have bought 3 iPads! #sxsw@mention Room#NokiaConnects
# 1818  Privacy Could Headline Google Circles Social Network Reveal Later Today [Social Networks] {link} #ACLU #GoogleCircles #SXSW

# %%
# data types of the features
df_train.dtypes
# Out:
# tweet_id     int64
# tweet        object
# sentiment    int64
# dtype: object

# %%
# data distribution of target variable
class_count = df_train['sentiment'].value_counts()
class_count

The sentiment labels are:

0: Negative, 1: Neutral, 2: Positive, 3: Can't Tell

#### Bar Plot of value counts

x = np.array(class_count.index)
y = np.array(class_count.values)
plt.figure(figsize=(10,5))
sns.barplot(x,y)
plt.xlabel('Sentiment')
plt.ylabel('Number of tweets')

# Number of tweets in each Dataset
print('Number of sentences in training set:',len(df_train['tweet_id'].unique()))
print('Number of sentences in test set:',len(df_test['tweet_id'].unique()))
# print('Average words per sentence in train:',df_train.groupby('tweet_id')['sentiment'].count().mean())
# print('Average words per sentence in test:',df_test.groupby('tweet_id')['sentiment'].count().mean())

# Shape of the Datasets
df_train.shape, df_test.shape

#### Using Word Clouds to see the higher fequency words from each sentiment¶


# # stopwords = set(STOPWORDS)
# # def show_wordcloud(data, title = None):
# #     wordcloud = WordCloud(
# #         background_color='black',
# #         stopwords=stopwords,
# #         max_words=10000,
# #         max_font_size=40, 
# #         scale=3,
# #         random_state=1 # chosen at random by flipping a coin; it was heads
# # ).generate(str(data))

# #     fig = plt.figure(1, figsize=(15, 15))
# #     plt.axis('off')
# #     if title: 
# #         fig.suptitle(title, fontsize=20)
# #         fig.subplots_adjust(top=2.3)

# #     plt.imshow(wordcloud)
# #     plt.show()

# # show_wordcloud(df_train['tweet'],'Most Common Words from the whole corpus')

# show_wordcloud(df_train[df_train['sentiment'] == 0]['tweet'],'Negative Tweets')

# # df_train['tweet']
# show_wordcloud(df_train[df_train['sentiment'] == 1]['tweet'],'Neutral Tweets')

# show_wordcloud(df_train[df_train['sentiment'] == 2]['tweet'],'Positive Tweets')

# show_wordcloud(df_train[df_train['sentiment'] == 3]['tweet'],'Can\'t say Tweets')

df_train.iloc[500:600].head()

df_train.isna().sum()

df_train['tweet'].dtype

# df_train['text_length'] = df_train['tweet'].apply(len)
# df_train[['tweet_id','text_length','tweet']].head()

df_train[ df_train['sentiment'] == 0 ].head()

df_train.dropna(inplace=True)

# train_pos = df_train[ df_train['sentiment'] == 2 ]
# train_pos = train_pos['tweet']
# train_neg = df_train[ df_train['sentiment'] == 0]
# train_neg = train_neg['tweet']

# def wordcloud_draw(data, color = 'black'):
#     words = ' '.join(data)
#     cleaned_word = " ".join([word for word in words.split()
#                             if 'http' not in word
#                                 and not word.startswith('@')
#                                 and not word.startswith('#')
#                                 and not word.startswith('{')
#                                 and word != 'RT'
#                                 and word != 'quot'
#                                 and word != 'amp'
#                             ])
#     wordcloud = WordCloud(stopwords=STOPWORDS,
#                       background_color=color,
#                       width=2500,
#                       height=2000
#                      ).generate(cleaned_word)
#     plt.figure(1,figsize=(13, 13))
#     plt.imshow(wordcloud)
#     plt.axis('off')
#     plt.show()
    
# print("Positive tweets")
# # wordcloud_draw(train_pos,'white')
# print("Negative tweets")
# # wordcloud_draw(train_neg)
# print('most common words from the corpus')
# wordcloud_draw(df_train['tweet'])



    

# # pip install plotly==4.7.1

# import plotly.graph_objects as go

# # fig = go.Figure(go.Funnelarea(
# #     text =df_train.sentiment,
# #     values = df_train.tweet,
# #     title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
# #     ))
# # fig.show()

# from collections import Counter

# # df_train['temp_list'] = df_train['tweet'].apply(lambda x:str(x).split())
# # top = Counter([item for sublist in df_train['tweet'] for item in sublist])
# # temp = pd.DataFrame(top.most_common(20))
# # temp.columns = ['Common_words','count']
# # temp.style.background_gradient(cmap='Blues')

# # fig = df_train['tweet'].bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h', 
# #              width=700, height=700,color='Common_words')
# # fig.show()

# # def remove_stopword(x):
# #     return [y for y in x if y not in stopwords.words('english')]
# # df_train['tweet_stopwords'] = df_train['tweet'].apply(lambda x:remove_stopword(x))

# # top = Counter([item for sublist in train['temp_list'] for item in sublist])
# # temp = pd.DataFrame(top.most_common(20))
# # temp = temp.iloc[1:,:]
# # temp.columns = ['Common_words','count']
# # temp.style.background_gradient(cmap='Purples')

# # fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
# # fig.show()

# raw_text = [word for word_list in df_train[['tweet']] for word in word_list]


# def words_unique(sentiments,numwords,raw_words):
#     '''
#     Input:
#         segment - Segment category (ex. 'Neutral');
#         numwords - how many specific words do you want to see in the final result; 
#         raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
#     Output: 
#         dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

#     '''
#     allother = []
#     for item in df_train[df_train.sentiment != sentiments]['tweet']:
#         for word in item:
#             allother .append(word)
#     allother  = list(set(allother ))
    
#     specificnonly = [x for x in raw_text if x not in allother]
    
#     mycounter = Counter()
    
#     for item in df_train[df_train.sentiment == sentiments]['tweet']:
#         for word in item:
#             mycounter[word] += 1
#     keep = list(specificnonly)
    
#     for word in list(mycounter):
#         if word not in keep:
#             del mycounter[word]
    
#     Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
#     return Unique_words

# # Unique_Positive= words_unique(2, 20, raw_text)
# # print("The top 20 unique words in Positive Tweets are:")
# # Unique_Positive.style.background_gradient(cmap='Greens')
# Out:
#   File "<ipython-input-10-ebd459a8373b>", line 5
#     The sentiment labels are:
#                 ^
# SyntaxError: invalid syntax

# %%
# # alphanumeric=['' for i in range(7274)]

# # for i in range(7274):
# #     a_string = df_train['tweet'][i]
# #     if type(a_string)!=float:
# #         for character in a_string:
# #             if character.isalnum():
# #                 alphanumeric[i] += character
# #             elif character ==" ":
# #                 alphanumeric[i] +=character
# # alphanumeric

# # df_train.head()

# cdf['tweet'] = alphanumeric

# cdf.head()

# # Creating Tokens
# # tokenized_sents = [word_tokenize(i) for i in alphanumeric]
# # tokenized_sents

# ## Bag of Words

#  - It is a method to extract features from text documents.
#  - These features can be used for training ML algorithms.
#  - It is basically a vocabulary of all unique words occuring in the document in the training dataset.



# # Bow_1 has list of words row wise so like every tweet is converted into a list of words.

# bow_1 = cdf['tweet'].apply(lambda x:word_tokenize(str(x)))
# # print(bow_1.head())

# # Bow_2 has Nested list form of Bow_1 so every list in Bow_1 is combined into one big Nested list.

# bow_2 = []
# for i in bow_1:
#     bow_2.append(i)
# # bow_2

# # Bow_3 has Nested list flattened into a simple list so all the words used in tweets is present in Bow_3 as an element
# # and no nested list present but it has repetition of elements still present.

# bow_3 = []
# def reemovNestings(l): 
#     for i in l: 
#         if type(i) == list: 
#             reemovNestings(i) 
#         else: 
#             bow_3.append(i)
# reemovNestings(bow_2)
# bow_3

# # Bow_final has all unique words of tweets ready to be converted into features for ML Model.

# # bow_final = list(set(bow_3))
# # bow_final

# len(bow_1)

# # bow_1

# # Lemmi
# #initialise word lematizer
# lemmatizer = WordNetLemmatizer()

# for i in range(len(bow_1)):
#     print(lemmatizer.lemmatize(bow_1[i]))


# # cdf['tweet'].head()

# # lemmatizer.lemmatize(cdf['tweet'])

# cdf['tweet'] = [lemmatizer.lemmatize(i[:]) for i in cdf['tweet']]

# df_train['tweet'].head()

# cdf['tweet'].head()

# # type(cdf['tweet'][0])

# # bow_5 = cdf['tweet'].apply(lambda x:lemmatizer.lemmatize(str(x)))

# ps=PorterStemmer()

# cdf['tweet_stem'] =  [ps.stem(i[:]) for i in cdf['tweet']]

# # cdf['tweet_stem']

# %% [markdown]
# ## Data Preprocessing

# %%
# Creating copy of the train dataset
cdf = df_train.copy()

# making tweets to lower case
cdf['tweet']  = cdf['tweet'].str.lower()

# to remove html tags from the tweets using html praser
# Importing HTMLParser
from html.parser import HTMLParser
html = HTMLParser()

# checking for null values
cdf['tweet'].isna().sum()

# droping the single null value present in the train dataset
cdf.dropna(inplace=True)

# Created a new columns i.e. tweet_html which do not contain html tags
cdf['tweet_html'] = cdf['tweet'].apply(lambda x: html.unescape(x))
cdf
# Out:
#       tweet_id  \
# 0     1701
# 1     1851
# 2     2689
# 3     4525
# 4     3604
# 5     966
# 6     1395
# 7     8182
# 8     8835
# 9     883
# 10    6398
# 11    2369
# 12    3944
# 13    6909
# 14    7917
# 15    5849
# 16    1955
# 17    1472
# 18    4730
# 19    2166
# 20    3497
# 21    165
# 22    1352
# 23    6431
# 24    634
# 25    4544
# 26    568
# 27    775
# 28    5368
# 29    3087
# ...    ...
# 7244  4996
# 7245  4887
# 7246  5027
# 7247  409
# 7248  392
# 7249  2556
# 7250  5467
# 7251  5290
# 7252  7145
# 7253  4635
# 7254  780
# 7255  7424
# 7256  6739
# 7257  3891
# 7258  4284
# 7259  1179
# 7260  6157
# 7261  3525
# 7262  8056
# 7263  1273
# 7264  8775
# 7265  287
# 7266  3362
# 7267  5222
# 7268  8644
# 7269  3343
# 7270  5334
# 7271  5378
# 7272  2173
# 7273  3162
#
#                                                                                                                                                  tweet  \
# 0     #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1     learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2     one of the most in-your-face ex. of stealing the show in yrs rt @mention &quot;at #sxsw, apple schools the mkt experts&quot;  {link}
# 3     this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4     line outside the apple store in austin waiting for the new ipad #sxsw  {link}
# 5     #technews one lone dude awaits ipad 2 at appleûªs sxsw store {link} #tech_news #apple #ipad_2 #sxsw #tablets #tech
# 6     sxsw tips, prince, npr videos, toy shopping with zuckerberg.\r\n{link}  #sxsw  #ipad
# 7     nu user rt @mention new #ubersocial for #iphone now in the app store includes uberguide to #sxsw sponsored by #mashable
# 8     free #sxsw sampler on itunes {link} #freemusic
# 9     i think i might go all weekend without seeing the same ipad case twice... #sxsw
# 10    rt @mention official #sxsw app û÷sxsw goûª bit.ly/hmiiga #android #iphone #ipad
# 11    it's official! i'm buying an ipad. #sxsw #elevate
# 12    they're giving away ipad 2's, x boxes and books at @mention #sxsw #techenvy
# 13    rt @mention we're officially at #sxsw! come by the @mention grill, mention us w/ #zazzlsxsw and youûªll get to make your own iphone case!
# 14    #companies to watch, from the #sxsw trade show floor {link} #apps #features #hardware #ipad #iphone
# 15    rt @mention google marissa mayer, future of location: augmented reality, contextual discovery, make smartphones smarter. #sxsw
# 16    dl the #calyp app to get into #calyp casa at #sxsw the free mobile app is available in itunes app store &amp; android market. see u there!
# 17    well yeah.  music &gt; iphone nerds rt @mention my god, cute girls everywhere...i love when interactive ends and music begins #sxsw
# 18    apple opens pop up store at sxsw {link} via @mention #apple #ipad2 #technology #itunes #sxsw
# 19    @mention atleast you are at #sxsw. i'm not there and i have no ipad. #doubleloser
# 20    cue the choir music #sxsw  @mention apple store, sxsw {link}
# 21    anyone at #sxsw want an ipad 2? i'm in line and will pick one up for someone willing to pay me 50 for me to grab 1 for you?
# 22    _¼ûä___ü ___¡  _____«_µ... &gt;&gt; @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 23    rt @mention p.s. @mention and google throw a b!tchin' party. shout out to the spazmatics #sxsw
# 24    .@mention i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 25    does anyone know if google did talk about #circles at #sxsw ?
# 26    ûï@mention google set to launch new social network #circles today at #sxswû @mention  @mention
# 27    google to launch major new social network called circles, possibly today {link} #sxsw
# 28    standing on a long line surrounded by unemployed techies from brooklyn!  am i at #sxsw or at the apple store on 5th ave waiting for ipad?!
# 29    wow! *something ventured* was a kick ass film... google or blekko it for details. good choice @mention #sxsw #startups #vc #movie #awesome
# ...                                                                                                                                          ...
# 7244  google looks to the future with mobile, location-based devices | {link}  #sxsw
# 7245  fantastico! rt @mention marissa mayer: google will connect the digital &amp; physical worlds through mobile - {link} #sxsw
# 7246  rt @mention \r\nan apple pop-uitp store at #sxsw? there goes my impulse control. j.mp/i41h53 &lt;- see, this is why it's good i'm not there #ooc
# 7247  wishes he could be at the @mention / @mention / @mention party at #sxsw instead of doing homework for tomorrow...
# 7248  tomorrow, charles chen will be speaking about android and chromeos access @mention the google booth in exhibit hall 3 @mention 1pm #sxsw
# 7249  z7: lead don't follow {link} [codes valid: 4:00-7:59:59p 03/11/11] #infektd #sxsw #zlf
# 7250  rt @mention apple sets up 5,000-square-foot temporary store at #sxsw to sell new ipads, test potential traffic {link}
# 7251  rt @mention #sxsw gear bag: ipad 2, iphone, mophie. traveling light this year! {link}
# 7252  û÷viagra for your communicationsûª @mention launches android app at #sxsw {link} happy to see expansion beyond outlook plugin.
# 7253  interesting! rt @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 7254  google to launch major new social network called circles, possibly today {link} #sxsw @mention
# 7255  sweet, apple's opening a pop-up shop in the scarbrough building on congress for the ipad 2 - {link} /via @mention #sxsw
# 7256  rt @mention the future is about networks, not just data. that's why google may not win long term #sxsw #web3 #saatchiny
# 7257  did you miss google's vp of search, marissa mayer last week? listen to the interview here  {link} #sxsw
# 7258  @mention massive lines at #sxsw apple store...agree, i can wait. perhaps late early adopter?
# 7259  exploring the world in 3d with xml combines google earth w/ location of individuals to show where you've been over time. so cool! #sxsw
# 7260  rt @mention ipad hipster #austincrowd #sxsw {link}
# 7261  the new whrrl app is now live in the iphone app store and android marketplace. get it while it's hot! (just in time for #sxsw!) via @mention
# 7262  come see something new about google sketchup pro at #sxsw {link} via @mention google sketchup blog
# 7263  there are two apple stores in atx!! rt @mention the ipad 2 goes on sale next friday...the austin apple store is going to be busy! #sxswû
# 7264  heading over to ballroom b 'your mom has an ipad-designing for boomers' #sxsw
# 7265  at #sxsw, apple schools the marketing experts | cnet blogs {link} #austin #atx #retail
# 7266  @mention great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 7267  the session #designingforkids is changing my mind about my future kid's relationship with the iphone. #sapient #sxsw
# 7268  great visualisation of the ghost movement logic in pacman during the google doodles session @mention #sxsw. more details here. {link}
# 7269  @mention google plze tammi.  i'm in middle of #sxsw craziness and everything is soooooo busy!
# 7270  rt @mention ÷¼ are you all set? ÷_ {link} ÷_ #edchat #musedchat #sxsw #sxswi #newtwitter
# 7271  rt @mention aha! found proof of lactation room, excuse me, &quot;mother's room,&quot; brought to you by google, at last year's #sxsw. {link}
# 7272  we just launched our ipad app at #sxsw! get all the details + the first edition free: {link}
# 7273  the next fin serv battle is vs apple, goog, mobile operators. they have consumer loyalty and tons of cash (vs. banks) #bankinnovate #sxsw
#
#       sentiment  \
# 0     1
# 1     1
# 2     2
# 3     0
# 4     1
# 5     1
# 6     1
# 7     1
# 8     2
# 9     2
# 10    3
# 11    2
# 12    2
# 13    1
# 14    1
# 15    1
# 16    1
# 17    2
# 18    1
# 19    1
# 20    1
# 21    1
# 22    2
# 23    2
# 24    0
# 25    1
# 26    1
# 27    1
# 28    3
# 29    1
# ...  ..
# 7244  1
# 7245  2
# 7246  1
# 7247  1
# 7248  1
# 7249  1
# 7250  1
# 7251  1
# 7252  2
# 7253  1
# 7254  1
# 7255  2
# 7256  0
# 7257  1
# 7258  2
# 7259  2
# 7260  2
# 7261  2
# 7262  1
# 7263  2
# 7264  1
# 7265  2
# 7266  2
# 7267  3
# 7268  2
# 7269  1
# 7270  1
# 7271  1
# 7272  1
# 7273  1
#
#                                                                                                                                          tweet_html
# 0     #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1     learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2     one of the most in-your-face ex. of stealing the show in yrs rt @mention "at #sxsw, apple schools the mkt experts"  {link}
# 3     this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4     line outside the apple store in austin waiting for the new ipad #sxsw  {link}
# 5     #technews one lone dude awaits ipad 2 at appleûªs sxsw store {link} #tech_news #apple #ipad_2 #sxsw #tablets #tech
# 6     sxsw tips, prince, npr videos, toy shopping with zuckerberg.\r\n{link}  #sxsw  #ipad
# 7     nu user rt @mention new #ubersocial for #iphone now in the app store includes uberguide to #sxsw sponsored by #mashable
# 8     free #sxsw sampler on itunes {link} #freemusic
# 9     i think i might go all weekend without seeing the same ipad case twice... #sxsw
# 10    rt @mention official #sxsw app û÷sxsw goûª bit.ly/hmiiga #android #iphone #ipad
# 11    it's official! i'm buying an ipad. #sxsw #elevate
# 12    they're giving away ipad 2's, x boxes and books at @mention #sxsw #techenvy
# 13    rt @mention we're officially at #sxsw! come by the @mention grill, mention us w/ #zazzlsxsw and youûªll get to make your own iphone case!
# 14    #companies to watch, from the #sxsw trade show floor {link} #apps #features #hardware #ipad #iphone
# 15    rt @mention google marissa mayer, future of location: augmented reality, contextual discovery, make smartphones smarter. #sxsw
# 16    dl the #calyp app to get into #calyp casa at #sxsw the free mobile app is available in itunes app store & android market. see u there!
# 17    well yeah.  music > iphone nerds rt @mention my god, cute girls everywhere...i love when interactive ends and music begins #sxsw
# 18    apple opens pop up store at sxsw {link} via @mention #apple #ipad2 #technology #itunes #sxsw
# 19    @mention atleast you are at #sxsw. i'm not there and i have no ipad. #doubleloser
# 20    cue the choir music #sxsw  @mention apple store, sxsw {link}
# 21    anyone at #sxsw want an ipad 2? i'm in line and will pick one up for someone willing to pay me 50 for me to grab 1 for you?
# 22    _¼ûä___ü ___¡  _____«_µ... >> @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 23    rt @mention p.s. @mention and google throw a b!tchin' party. shout out to the spazmatics #sxsw
# 24    .@mention i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 25    does anyone know if google did talk about #circles at #sxsw ?
# 26    ûï@mention google set to launch new social network #circles today at #sxswû @mention  @mention
# 27    google to launch major new social network called circles, possibly today {link} #sxsw
# 28    standing on a long line surrounded by unemployed techies from brooklyn!  am i at #sxsw or at the apple store on 5th ave waiting for ipad?!
# 29    wow! *something ventured* was a kick ass film... google or blekko it for details. good choice @mention #sxsw #startups #vc #movie #awesome
# ...                                                                                                                                          ...
# 7244  google looks to the future with mobile, location-based devices | {link}  #sxsw
# 7245  fantastico! rt @mention marissa mayer: google will connect the digital & physical worlds through mobile - {link} #sxsw
# 7246  rt @mention \r\nan apple pop-uitp store at #sxsw? there goes my impulse control. j.mp/i41h53 <- see, this is why it's good i'm not there #ooc
# 7247  wishes he could be at the @mention / @mention / @mention party at #sxsw instead of doing homework for tomorrow...
# 7248  tomorrow, charles chen will be speaking about android and chromeos access @mention the google booth in exhibit hall 3 @mention 1pm #sxsw
# 7249  z7: lead don't follow {link} [codes valid: 4:00-7:59:59p 03/11/11] #infektd #sxsw #zlf
# 7250  rt @mention apple sets up 5,000-square-foot temporary store at #sxsw to sell new ipads, test potential traffic {link}
# 7251  rt @mention #sxsw gear bag: ipad 2, iphone, mophie. traveling light this year! {link}
# 7252  û÷viagra for your communicationsûª @mention launches android app at #sxsw {link} happy to see expansion beyond outlook plugin.
# 7253  interesting! rt @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 7254  google to launch major new social network called circles, possibly today {link} #sxsw @mention
# 7255  sweet, apple's opening a pop-up shop in the scarbrough building on congress for the ipad 2 - {link} /via @mention #sxsw
# 7256  rt @mention the future is about networks, not just data. that's why google may not win long term #sxsw #web3 #saatchiny
# 7257  did you miss google's vp of search, marissa mayer last week? listen to the interview here  {link} #sxsw
# 7258  @mention massive lines at #sxsw apple store...agree, i can wait. perhaps late early adopter?
# 7259  exploring the world in 3d with xml combines google earth w/ location of individuals to show where you've been over time. so cool! #sxsw
# 7260  rt @mention ipad hipster #austincrowd #sxsw {link}
# 7261  the new whrrl app is now live in the iphone app store and android marketplace. get it while it's hot! (just in time for #sxsw!) via @mention
# 7262  come see something new about google sketchup pro at #sxsw {link} via @mention google sketchup blog
# 7263  there are two apple stores in atx!! rt @mention the ipad 2 goes on sale next friday...the austin apple store is going to be busy! #sxswû
# 7264  heading over to ballroom b 'your mom has an ipad-designing for boomers' #sxsw
# 7265  at #sxsw, apple schools the marketing experts | cnet blogs {link} #austin #atx #retail
# 7266  @mention great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) & matt mullenweg (wordpress)
# 7267  the session #designingforkids is changing my mind about my future kid's relationship with the iphone. #sapient #sxsw
# 7268  great visualisation of the ghost movement logic in pacman during the google doodles session @mention #sxsw. more details here. {link}
# 7269  @mention google plze tammi.  i'm in middle of #sxsw craziness and everything is soooooo busy!
# 7270  rt @mention ÷¼ are you all set? ÷_ {link} ÷_ #edchat #musedchat #sxsw #sxswi #newtwitter
# 7271  rt @mention aha! found proof of lactation room, excuse me, "mother's room," brought to you by google, at last year's #sxsw. {link}
# 7272  we just launched our ipad app at #sxsw! get all the details + the first edition free: {link}
# 7273  the next fin serv battle is vs apple, goog, mobile operators. they have consumer loyalty and tons of cash (vs. banks) #bankinnovate #sxsw
#
# [7273 rows x 4 columns]

# %%
cdf.shape
# Out:
# (7273, 4)

# %%
cdf['tweet_html'].head()
# Out:
# 0    #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1    learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2    one of the most in-your-face ex. of stealing the show in yrs rt @mention "at #sxsw, apple schools the mkt experts"  {link}
# 3    this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4    line outside the apple store in austin waiting for the new ipad #sxsw  {link}
# Name: tweet_html, dtype: object

# %%
# Adding unnecessary char to stop words
stop_words = list(set(stopwords.words('english')))+list(punctuation)+['``', "'s", "...", "n't"]

# creating tokens
cdf['tweet_tokens'] = [nltk.word_tokenize(x) for x in cdf['tweet_html']]

# Removing stop words 
cdf['tweet_tokens'] = cdf['tweet_tokens'].apply(lambda row: [word for word in row if word not in stop_words])

#Applying the stemming

# stemmer = PorterStemmer()
# cdf['tweet_tokens'] = cdf['tweet_tokens'].apply(lambda x: [stemmer.stem(i) for i in x])
# cdf['tokenized_tweet'] = cdf['tweet_tokens'].apply(lambda x: ' '.join(x))
# cdf.head()

#Applying the lemmatizer

# lemma = WordNetLemmatizer()
# cdf['tweet_tokens'] = cdf['tweet_tokens'].apply(lambda x: [lemma.lemmatize(i) for i in x])
# cdf['tweet_tokens'] = cdf['tweet_tokens'].apply(lambda x: ' '.join(x))
cdf.head()
# Out:
#    tweet_id  \
# 0  1701
# 1  1851
# 2  2689
# 3  4525
# 4  3604
#
#                                                                                                                                              tweet  \
# 0  #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1  learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2  one of the most in-your-face ex. of stealing the show in yrs rt @mention &quot;at #sxsw, apple schools the mkt experts&quot;  {link}
# 3  this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4  line outside the apple store in austin waiting for the new ipad #sxsw  {link}
#
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  0
# 4  1
#
#                                                                                                                                     tweet_html  \
# 0  #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1  learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2  one of the most in-your-face ex. of stealing the show in yrs rt @mention "at #sxsw, apple schools the mkt experts"  {link}
# 3  this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4  line outside the apple store in austin waiting for the new ipad #sxsw  {link}
#
#                                                                                                                  tweet_tokens
# 0  [sxswnui, sxsw, apple, defining, language, touch, different, dialects, becoming, smaller]
# 1  [learning, ab, google, doodles, doodles, light, funny, innovative, exceptions, significant, occasions, googledoodle, sxsw]
# 2  [one, in-your-face, ex, stealing, show, yrs, rt, mention, sxsw, apple, schools, mkt, experts, '', link]
# 3  [iphone, sxsw, app, would, b, pretty, awesome, crash, every, 10mins, extended, browsing, fuckit, illmakeitwork]
# 4  [line, outside, apple, store, austin, waiting, new, ipad, sxsw, link]

# %%
print("Before treating Stopwords :")
print(' ')
print(cdf.iloc[1,1])
print(' ')
print('**********************************************************')
print(' ')
print('After treating stopwords and punctuations and applying Tokenization  :')
print(' ')
print(cdf.iloc[1,4])
# Out:
# Before treating Stopwords :
#
# learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
#
# **********************************************************
#
# After treating stopwords and punctuations and applying Tokenization  :
#
# ['learning', 'ab', 'google', 'doodles', 'doodles', 'light', 'funny', 'innovative', 'exceptions', 'significant', 'occasions', 'googledoodle', 'sxsw']

# %% [markdown]
# **Before treating Stopwords :**
#
# learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
#
# **********************************************************
#
# **After treating stopwords and punctuations and applying Tokenization  :**
#
# ['learning', 'ab', 'google', 'doodles', 'doodles', 'light', 'funny', 'innovative', 'exceptions', 'significant', 'occasions', 'googledoodle', 'sxsw']

# %% [markdown]
# ## Features Extraction

# %%
def feature_extraction(data, method = "tfidf"):
    #arguments: data = all the tweets in the form of array, method = type of feature extracter
    #methods of feature extractions: "tfidf" and "doc2vec"
    if method == "tfidf":
        from sklearn.feature_extraction.text import TfidfVectorizer
        tfv=TfidfVectorizer(sublinear_tf=True) # we need to give proper stopwords list for better performance
        features=tfv.fit_transform(data)
        
    else:
        return "Incorrect inputs"
    return features

# %%
vector = feature_extraction(cdf['tweet_tokens'],method='tfidf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-64d30545d7d2> in <module>
# ----> 1 vector = feature_extraction(cdf['tweet_tokens'],method='tfidf')
#
# <ipython-input-17-dfd51ec6b12f> in feature_extraction(data, method)
#       5         from sklearn.feature_extraction.text import TfidfVectorizer
#       6         tfv=TfidfVectorizer(sublinear_tf=True) # we need to give proper stopwords list for better performance
# ----> 7         features=tfv.fit_transform(data)
#       8
#       9     else:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1857         """
#    1858         self._check_params()
# -> 1859         X = super().fit_transform(raw_documents)
#    1860         self._tfidf.fit(X)
#    1861         # X is already a transformed view of raw_documents so
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1218
#    1219         vocabulary, X = self._count_vocab(raw_documents,
# -> 1220                                           self.fixed_vocabulary_)
#    1221
#    1222         if self.binary:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1129         for doc in raw_documents:
#    1130             feature_counter = {}
# -> 1131             for feature in analyze(doc):
#    1132                 try:
#    1133                     feature_idx = vocabulary[feature]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     101     else:
#     102         if preprocessor is not None:
# --> 103             doc = preprocessor(doc)
#     104         if tokenizer is not None:
#     105             doc = tokenizer(doc)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _preprocess(doc, accent_function, lower)
#      66     """
#      67     if lower:
# ---> 68         doc = doc.lower()
#      69     if accent_function is not None:
#      70         doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
initial_tfidf = vector.toarray()

# %%
initial_tfidf.shape
# Out:
# (7273, 8184)

# %%
#Splitting the dataset into train and test
X_train,X_test,y_train,y_test = train_test_split(initial_tfidf,cdf['sentiment'],test_size=0.4,random_state=42)

#Initialising the logistic regression model
log_reg = LogisticRegression(random_state=42)

#Fitting the model with train data
log_reg.fit(X_train,y_train)

#Finding the accuracy score of model on test data
acc = log_reg.score(X_test,y_test)
log_predict = log_reg.predict(X_test)
f1 = f1_score(log_predict,y_test,average='weighted')

print ("Accuracy Score: ", acc)
print('f1 score:', f1)
# Out:
# Accuracy Score:  0.6769759450171822
# f1 score: 0.717694696068809

# %%
from sklearn.metrics import f1_score ,roc_auc_score
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
y_pred = nb.predict(X_test)
nb_acc = nb.score(X_test,y_test)
f1 = f1_score(y_pred,y_test,average='weighted')

print ("Accuracy Score: ", nb_acc)
print('f1 score:', f1)
# Out:
# Accuracy Score:  0.6405498281786941
# f1 score: 0.7246448772268967

# %%
# def train_classifier(features, label, classifier = "logistic_regression"):
#     #arguments: features = output of feature_extraction(...), label = labels in array form, classifier = type of classifier 
# #     from sklearn.metrics import roc_auc_score # we will use auc as the evaluation metric
#     if classifier == "logistic_regression": # auc (train data): 0.8780618441250002
#         from sklearn.linear_model import LogisticRegression
#         model = LogisticRegression(C=1.)
#     elif classifier == "naive_bayes": # auc (train data): 0.8767891829687501
#         from sklearn.naive_bayes import MultinomialNB
#         model = MultinomialNB()
#     elif classifier == "svm": # can't use sklearn svm, as way too much of data so way to slow. have to use tensorflow for svm
#         from sklearn.svm import SVC
#         model = SVC()
#     else:
#         print("Incorrect selection of classifier")
#     #fit model to data
#     model.fit(features, label)
#     #make prediction on the same (train) data
#     probability_to_be_positive = model.predict_proba(features)[:,1]
#     #chcek AUC(Area Undet the Roc Curve) to see how well the score discriminates between negative and positive
#     print ("auc (train data):" , roc_auc_score(label, probability_to_be_positive))
#     #print top 10 scores as a sanity check
#     print ("top 10 scores: ", probability_to_be_positive[:10])
#     #print f1 score 
#     label_pred = model.predict(X_test)
#     print('f1 score: ',f1_score(label_pred,label,average='weighted'))

# %%
# train_classifier(features=X_train,label=y_train,classifier='naive_bayes')

# %%
def get_hashtags(text, handle_space=True):

    if handle_space:
        space = r"#\s+"
        text = re.sub(space, "#", str(text).lower()).strip()
    
    hash_tags = r"#\S+"
    
    return " ".join(re.findall(hash_tags, text))

# %%
cdf['hashtags'] = df_train.tweet.apply(get_hashtags)

# %%
# cdf
# Out:
#       tweet_id  \
# 0     1701
# 1     1851
# 2     2689
# 3     4525
# 4     3604
# 5     966
# 6     1395
# 7     8182
# 8     8835
# 9     883
# 10    6398
# 11    2369
# 12    3944
# 13    6909
# 14    7917
# 15    5849
# 16    1955
# 17    1472
# 18    4730
# 19    2166
# 20    3497
# 21    165
# 22    1352
# 23    6431
# 24    634
# 25    4544
# 26    568
# 27    775
# 28    5368
# 29    3087
# ...    ...
# 7244  4996
# 7245  4887
# 7246  5027
# 7247  409
# 7248  392
# 7249  2556
# 7250  5467
# 7251  5290
# 7252  7145
# 7253  4635
# 7254  780
# 7255  7424
# 7256  6739
# 7257  3891
# 7258  4284
# 7259  1179
# 7260  6157
# 7261  3525
# 7262  8056
# 7263  1273
# 7264  8775
# 7265  287
# 7266  3362
# 7267  5222
# 7268  8644
# 7269  3343
# 7270  5334
# 7271  5378
# 7272  2173
# 7273  3162
#
#                                                                                                                                                  tweet  \
# 0     #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1     learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2     one of the most in-your-face ex. of stealing the show in yrs rt @mention &quot;at #sxsw, apple schools the mkt experts&quot;  {link}
# 3     this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4     line outside the apple store in austin waiting for the new ipad #sxsw  {link}
# 5     #technews one lone dude awaits ipad 2 at appleûªs sxsw store {link} #tech_news #apple #ipad_2 #sxsw #tablets #tech
# 6     sxsw tips, prince, npr videos, toy shopping with zuckerberg.\r\n{link}  #sxsw  #ipad
# 7     nu user rt @mention new #ubersocial for #iphone now in the app store includes uberguide to #sxsw sponsored by #mashable
# 8     free #sxsw sampler on itunes {link} #freemusic
# 9     i think i might go all weekend without seeing the same ipad case twice... #sxsw
# 10    rt @mention official #sxsw app û÷sxsw goûª bit.ly/hmiiga #android #iphone #ipad
# 11    it's official! i'm buying an ipad. #sxsw #elevate
# 12    they're giving away ipad 2's, x boxes and books at @mention #sxsw #techenvy
# 13    rt @mention we're officially at #sxsw! come by the @mention grill, mention us w/ #zazzlsxsw and youûªll get to make your own iphone case!
# 14    #companies to watch, from the #sxsw trade show floor {link} #apps #features #hardware #ipad #iphone
# 15    rt @mention google marissa mayer, future of location: augmented reality, contextual discovery, make smartphones smarter. #sxsw
# 16    dl the #calyp app to get into #calyp casa at #sxsw the free mobile app is available in itunes app store &amp; android market. see u there!
# 17    well yeah.  music &gt; iphone nerds rt @mention my god, cute girls everywhere...i love when interactive ends and music begins #sxsw
# 18    apple opens pop up store at sxsw {link} via @mention #apple #ipad2 #technology #itunes #sxsw
# 19    @mention atleast you are at #sxsw. i'm not there and i have no ipad. #doubleloser
# 20    cue the choir music #sxsw  @mention apple store, sxsw {link}
# 21    anyone at #sxsw want an ipad 2? i'm in line and will pick one up for someone willing to pay me 50 for me to grab 1 for you?
# 22    _¼ûä___ü ___¡  _____«_µ... &gt;&gt; @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 23    rt @mention p.s. @mention and google throw a b!tchin' party. shout out to the spazmatics #sxsw
# 24    .@mention i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 25    does anyone know if google did talk about #circles at #sxsw ?
# 26    ûï@mention google set to launch new social network #circles today at #sxswû @mention  @mention
# 27    google to launch major new social network called circles, possibly today {link} #sxsw
# 28    standing on a long line surrounded by unemployed techies from brooklyn!  am i at #sxsw or at the apple store on 5th ave waiting for ipad?!
# 29    wow! *something ventured* was a kick ass film... google or blekko it for details. good choice @mention #sxsw #startups #vc #movie #awesome
# ...                                                                                                                                          ...
# 7244  google looks to the future with mobile, location-based devices | {link}  #sxsw
# 7245  fantastico! rt @mention marissa mayer: google will connect the digital &amp; physical worlds through mobile - {link} #sxsw
# 7246  rt @mention \r\nan apple pop-uitp store at #sxsw? there goes my impulse control. j.mp/i41h53 &lt;- see, this is why it's good i'm not there #ooc
# 7247  wishes he could be at the @mention / @mention / @mention party at #sxsw instead of doing homework for tomorrow...
# 7248  tomorrow, charles chen will be speaking about android and chromeos access @mention the google booth in exhibit hall 3 @mention 1pm #sxsw
# 7249  z7: lead don't follow {link} [codes valid: 4:00-7:59:59p 03/11/11] #infektd #sxsw #zlf
# 7250  rt @mention apple sets up 5,000-square-foot temporary store at #sxsw to sell new ipads, test potential traffic {link}
# 7251  rt @mention #sxsw gear bag: ipad 2, iphone, mophie. traveling light this year! {link}
# 7252  û÷viagra for your communicationsûª @mention launches android app at #sxsw {link} happy to see expansion beyond outlook plugin.
# 7253  interesting! rt @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 7254  google to launch major new social network called circles, possibly today {link} #sxsw @mention
# 7255  sweet, apple's opening a pop-up shop in the scarbrough building on congress for the ipad 2 - {link} /via @mention #sxsw
# 7256  rt @mention the future is about networks, not just data. that's why google may not win long term #sxsw #web3 #saatchiny
# 7257  did you miss google's vp of search, marissa mayer last week? listen to the interview here  {link} #sxsw
# 7258  @mention massive lines at #sxsw apple store...agree, i can wait. perhaps late early adopter?
# 7259  exploring the world in 3d with xml combines google earth w/ location of individuals to show where you've been over time. so cool! #sxsw
# 7260  rt @mention ipad hipster #austincrowd #sxsw {link}
# 7261  the new whrrl app is now live in the iphone app store and android marketplace. get it while it's hot! (just in time for #sxsw!) via @mention
# 7262  come see something new about google sketchup pro at #sxsw {link} via @mention google sketchup blog
# 7263  there are two apple stores in atx!! rt @mention the ipad 2 goes on sale next friday...the austin apple store is going to be busy! #sxswû
# 7264  heading over to ballroom b 'your mom has an ipad-designing for boomers' #sxsw
# 7265  at #sxsw, apple schools the marketing experts | cnet blogs {link} #austin #atx #retail
# 7266  @mention great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 7267  the session #designingforkids is changing my mind about my future kid's relationship with the iphone. #sapient #sxsw
# 7268  great visualisation of the ghost movement logic in pacman during the google doodles session @mention #sxsw. more details here. {link}
# 7269  @mention google plze tammi.  i'm in middle of #sxsw craziness and everything is soooooo busy!
# 7270  rt @mention ÷¼ are you all set? ÷_ {link} ÷_ #edchat #musedchat #sxsw #sxswi #newtwitter
# 7271  rt @mention aha! found proof of lactation room, excuse me, &quot;mother's room,&quot; brought to you by google, at last year's #sxsw. {link}
# 7272  we just launched our ipad app at #sxsw! get all the details + the first edition free: {link}
# 7273  the next fin serv battle is vs apple, goog, mobile operators. they have consumer loyalty and tons of cash (vs. banks) #bankinnovate #sxsw
#
#       sentiment  \
# 0     1
# 1     1
# 2     2
# 3     0
# 4     1
# 5     1
# 6     1
# 7     1
# 8     2
# 9     2
# 10    3
# 11    2
# 12    2
# 13    1
# 14    1
# 15    1
# 16    1
# 17    2
# 18    1
# 19    1
# 20    1
# 21    1
# 22    2
# 23    2
# 24    0
# 25    1
# 26    1
# 27    1
# 28    3
# 29    1
# ...  ..
# 7244  1
# 7245  2
# 7246  1
# 7247  1
# 7248  1
# 7249  1
# 7250  1
# 7251  1
# 7252  2
# 7253  1
# 7254  1
# 7255  2
# 7256  0
# 7257  1
# 7258  2
# 7259  2
# 7260  2
# 7261  2
# 7262  1
# 7263  2
# 7264  1
# 7265  2
# 7266  2
# 7267  3
# 7268  2
# 7269  1
# 7270  1
# 7271  1
# 7272  1
# 7273  1
#
#                                                                                                                                          tweet_html  \
# 0     #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1     learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2     one of the most in-your-face ex. of stealing the show in yrs rt @mention "at #sxsw, apple schools the mkt experts"  {link}
# 3     this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4     line outside the apple store in austin waiting for the new ipad #sxsw  {link}
# 5     #technews one lone dude awaits ipad 2 at appleûªs sxsw store {link} #tech_news #apple #ipad_2 #sxsw #tablets #tech
# 6     sxsw tips, prince, npr videos, toy shopping with zuckerberg.\r\n{link}  #sxsw  #ipad
# 7     nu user rt @mention new #ubersocial for #iphone now in the app store includes uberguide to #sxsw sponsored by #mashable
# 8     free #sxsw sampler on itunes {link} #freemusic
# 9     i think i might go all weekend without seeing the same ipad case twice... #sxsw
# 10    rt @mention official #sxsw app û÷sxsw goûª bit.ly/hmiiga #android #iphone #ipad
# 11    it's official! i'm buying an ipad. #sxsw #elevate
# 12    they're giving away ipad 2's, x boxes and books at @mention #sxsw #techenvy
# 13    rt @mention we're officially at #sxsw! come by the @mention grill, mention us w/ #zazzlsxsw and youûªll get to make your own iphone case!
# 14    #companies to watch, from the #sxsw trade show floor {link} #apps #features #hardware #ipad #iphone
# 15    rt @mention google marissa mayer, future of location: augmented reality, contextual discovery, make smartphones smarter. #sxsw
# 16    dl the #calyp app to get into #calyp casa at #sxsw the free mobile app is available in itunes app store & android market. see u there!
# 17    well yeah.  music > iphone nerds rt @mention my god, cute girls everywhere...i love when interactive ends and music begins #sxsw
# 18    apple opens pop up store at sxsw {link} via @mention #apple #ipad2 #technology #itunes #sxsw
# 19    @mention atleast you are at #sxsw. i'm not there and i have no ipad. #doubleloser
# 20    cue the choir music #sxsw  @mention apple store, sxsw {link}
# 21    anyone at #sxsw want an ipad 2? i'm in line and will pick one up for someone willing to pay me 50 for me to grab 1 for you?
# 22    _¼ûä___ü ___¡  _____«_µ... >> @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 23    rt @mention p.s. @mention and google throw a b!tchin' party. shout out to the spazmatics #sxsw
# 24    .@mention i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 25    does anyone know if google did talk about #circles at #sxsw ?
# 26    ûï@mention google set to launch new social network #circles today at #sxswû @mention  @mention
# 27    google to launch major new social network called circles, possibly today {link} #sxsw
# 28    standing on a long line surrounded by unemployed techies from brooklyn!  am i at #sxsw or at the apple store on 5th ave waiting for ipad?!
# 29    wow! *something ventured* was a kick ass film... google or blekko it for details. good choice @mention #sxsw #startups #vc #movie #awesome
# ...                                                                                                                                          ...
# 7244  google looks to the future with mobile, location-based devices | {link}  #sxsw
# 7245  fantastico! rt @mention marissa mayer: google will connect the digital & physical worlds through mobile - {link} #sxsw
# 7246  rt @mention \r\nan apple pop-uitp store at #sxsw? there goes my impulse control. j.mp/i41h53 <- see, this is why it's good i'm not there #ooc
# 7247  wishes he could be at the @mention / @mention / @mention party at #sxsw instead of doing homework for tomorrow...
# 7248  tomorrow, charles chen will be speaking about android and chromeos access @mention the google booth in exhibit hall 3 @mention 1pm #sxsw
# 7249  z7: lead don't follow {link} [codes valid: 4:00-7:59:59p 03/11/11] #infektd #sxsw #zlf
# 7250  rt @mention apple sets up 5,000-square-foot temporary store at #sxsw to sell new ipads, test potential traffic {link}
# 7251  rt @mention #sxsw gear bag: ipad 2, iphone, mophie. traveling light this year! {link}
# 7252  û÷viagra for your communicationsûª @mention launches android app at #sxsw {link} happy to see expansion beyond outlook plugin.
# 7253  interesting! rt @mention google to launch major new social network called circles, possibly today {link} #sxsw
# 7254  google to launch major new social network called circles, possibly today {link} #sxsw @mention
# 7255  sweet, apple's opening a pop-up shop in the scarbrough building on congress for the ipad 2 - {link} /via @mention #sxsw
# 7256  rt @mention the future is about networks, not just data. that's why google may not win long term #sxsw #web3 #saatchiny
# 7257  did you miss google's vp of search, marissa mayer last week? listen to the interview here  {link} #sxsw
# 7258  @mention massive lines at #sxsw apple store...agree, i can wait. perhaps late early adopter?
# 7259  exploring the world in 3d with xml combines google earth w/ location of individuals to show where you've been over time. so cool! #sxsw
# 7260  rt @mention ipad hipster #austincrowd #sxsw {link}
# 7261  the new whrrl app is now live in the iphone app store and android marketplace. get it while it's hot! (just in time for #sxsw!) via @mention
# 7262  come see something new about google sketchup pro at #sxsw {link} via @mention google sketchup blog
# 7263  there are two apple stores in atx!! rt @mention the ipad 2 goes on sale next friday...the austin apple store is going to be busy! #sxswû
# 7264  heading over to ballroom b 'your mom has an ipad-designing for boomers' #sxsw
# 7265  at #sxsw, apple schools the marketing experts | cnet blogs {link} #austin #atx #retail
# 7266  @mention great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) & matt mullenweg (wordpress)
# 7267  the session #designingforkids is changing my mind about my future kid's relationship with the iphone. #sapient #sxsw
# 7268  great visualisation of the ghost movement logic in pacman during the google doodles session @mention #sxsw. more details here. {link}
# 7269  @mention google plze tammi.  i'm in middle of #sxsw craziness and everything is soooooo busy!
# 7270  rt @mention ÷¼ are you all set? ÷_ {link} ÷_ #edchat #musedchat #sxsw #sxswi #newtwitter
# 7271  rt @mention aha! found proof of lactation room, excuse me, "mother's room," brought to you by google, at last year's #sxsw. {link}
# 7272  we just launched our ipad app at #sxsw! get all the details + the first edition free: {link}
# 7273  the next fin serv battle is vs apple, goog, mobile operators. they have consumer loyalty and tons of cash (vs. banks) #bankinnovate #sxsw
#
#                                                                                                               tweet_tokens  \
# 0     sxswnui sxsw apple defining language touch different dialect becoming smaller
# 1     learning ab google doodle doodle light funny innovative exception significant occasion googledoodle sxsw
# 2     one in-your-face ex stealing show yr rt mention sxsw apple school mkt expert '' link
# 3     iphone sxsw app would b pretty awesome crash every 10mins extended browsing fuckit illmakeitwork
# 4     line outside apple store austin waiting new ipad sxsw link
# 5     technews one lone dude awaits ipad 2 appleûªs sxsw store link tech_news apple ipad_2 sxsw tablet tech
# 6     sxsw tip prince npr video toy shopping zuckerberg link sxsw ipad
# 7     nu user rt mention new ubersocial iphone app store includes uberguide sxsw sponsored mashable
# 8     free sxsw sampler itunes link freemusic
# 9     think might go weekend without seeing ipad case twice sxsw
# 10    rt mention official sxsw app û÷sxsw goûª bit.ly/hmiiga android iphone ipad
# 11    official 'm buying ipad sxsw elevate
# 12    're giving away ipad 2 x box book mention sxsw techenvy
# 13    rt mention 're officially sxsw come mention grill mention u w/ zazzlsxsw youûªll get make iphone case
# 14    company watch sxsw trade show floor link apps feature hardware ipad iphone
# 15    rt mention google marissa mayer future location augmented reality contextual discovery make smartphones smarter sxsw
# 16    dl calyp app get calyp casa sxsw free mobile app available itunes app store android market see u
# 17    well yeah music iphone nerd rt mention god cute girl everywhere love interactive end music begin sxsw
# 18    apple open pop store sxsw link via mention apple ipad2 technology itunes sxsw
# 19    mention atleast sxsw 'm ipad doubleloser
# 20    cue choir music sxsw mention apple store sxsw link
# 21    anyone sxsw want ipad 2 'm line pick one someone willing pay 50 grab 1
# 22    _¼ûä___ü ___¡ _____ « _µ mention google launch major new social network called circle possibly today link sxsw
# 23    rt mention p.s mention google throw b tchin party shout spazmatics sxsw
# 24    mention 3g iphone 3 hr tweeting rise_austin dead need upgrade plugin station sxsw
# 25    anyone know google talk circle sxsw
# 26    ûï mention google set launch new social network circle today sxswû mention mention
# 27    google launch major new social network called circle possibly today link sxsw
# 28    standing long line surrounded unemployed techie brooklyn sxsw apple store 5th ave waiting ipad
# 29    wow *something ventured* kick as film google blekko detail good choice mention sxsw startup vc movie awesome
# ...                                                                                                            ...
# 7244  google look future mobile location-based device link sxsw
# 7245  fantastico rt mention marissa mayer google connect digital physical world mobile link sxsw
# 7246  rt mention apple pop-uitp store sxsw go impulse control j.mp/i41h53 see good 'm ooc
# 7247  wish could mention mention mention party sxsw instead homework tomorrow
# 7248  tomorrow charles chen speaking android chromeos access mention google booth exhibit hall 3 mention 1pm sxsw
# 7249  z7 lead follow link code valid 4:00-7:59:59p 03/11/11 infektd sxsw zlf
# 7250  rt mention apple set 5,000-square-foot temporary store sxsw sell new ipads test potential traffic link
# 7251  rt mention sxsw gear bag ipad 2 iphone mophie traveling light year link
# 7252  û÷viagra communicationsûª mention launch android app sxsw link happy see expansion beyond outlook plugin
# 7253  interesting rt mention google launch major new social network called circle possibly today link sxsw
# 7254  google launch major new social network called circle possibly today link sxsw mention
# 7255  sweet apple opening pop-up shop scarbrough building congress ipad 2 link /via mention sxsw
# 7256  rt mention future network data google may win long term sxsw web3 saatchiny
# 7257  miss google vp search marissa mayer last week listen interview link sxsw
# 7258  mention massive line sxsw apple store agree wait perhaps late early adopter
# 7259  exploring world 3d xml combine google earth w/ location individual show 've time cool sxsw
# 7260  rt mention ipad hipster austincrowd sxsw link
# 7261  new whrrl app live iphone app store android marketplace get hot time sxsw via mention
# 7262  come see something new google sketchup pro sxsw link via mention google sketchup blog
# 7263  two apple store atx rt mention ipad 2 go sale next friday austin apple store going busy sxswû
# 7264  heading ballroom b 'your mom ipad-designing boomer sxsw
# 7265  sxsw apple school marketing expert cnet blog link austin atx retail
# 7266  mention great stuff fri sxsw marissa mayer google tim o'reilly tech books/conferences matt mullenweg wordpress
# 7267  session designingforkids changing mind future kid relationship iphone sapient sxsw
# 7268  great visualisation ghost movement logic pacman google doodle session mention sxsw detail link
# 7269  mention google plze tammi 'm middle sxsw craziness everything soooooo busy
# 7270  rt mention ÷¼ set ÷_ link ÷_ edchat musedchat sxsw sxswi newtwitter
# 7271  rt mention aha found proof lactation room excuse mother room '' brought google last year sxsw link
# 7272  launched ipad app sxsw get detail first edition free link
# 7273  next fin serv battle v apple goog mobile operator consumer loyalty ton cash vs. bank bankinnovate sxsw
#
#                                                       hashtags
# 0     #sxswnui #sxsw #apple
# 1     #googledoodle #sxsw
# 2     #sxsw,
# 3     #sxsw #fuckit #illmakeitwork
# 4     #sxsw
# 5     #technews #tech_news #apple #ipad_2 #sxsw #tablets #tech
# 6     #sxsw #ipad
# 7     #ubersocial #iphone #sxsw #mashable
# 8     #sxsw #freemusic
# 9     #sxsw
# 10    #sxsw #android #iphone #ipad
# 11    #sxsw #elevate
# 12    #sxsw #techenvy
# 13    #sxsw! #zazzlsxsw
# 14    #companies #sxsw #apps #features #hardware #ipad #iphone
# 15    #sxsw
# 16    #calyp #calyp #sxsw
# 17    #sxsw
# 18    #apple #ipad2 #technology #itunes #sxsw
# 19    #sxsw. #doubleloser
# 20    #sxsw
# 21    #sxsw
# 22    #sxsw
# 23    #sxsw
# 24    #rise_austin, #sxsw.
# 25    #circles #sxsw
# 26    #circles #sxswû
# 27    #sxsw
# 28    #sxsw
# 29    #sxsw #startups #vc #movie #awesome
# ...                                   ...
# 7244  #sxsw
# 7245  #sxsw
# 7246  #sxsw? #ooc
# 7247  #sxsw
# 7248  #sxsw
# 7249  #infektd #sxsw #zlf
# 7250  #sxsw
# 7251  #sxsw
# 7252  #sxsw
# 7253  #sxsw
# 7254  #sxsw
# 7255  #sxsw
# 7256  #sxsw #web3 #saatchiny
# 7257  #sxsw
# 7258  #sxsw
# 7259  #sxsw
# 7260  #austincrowd #sxsw
# 7261  #sxsw!)
# 7262  #sxsw
# 7263  #sxswû
# 7264  #sxsw
# 7265  #sxsw, #austin #atx #retail
# 7266  #sxsw:
# 7267  #designingforkids #sapient #sxsw
# 7268  #sxsw.
# 7269  #sxsw
# 7270  #edchat #musedchat #sxsw #sxswi #newtwitter
# 7271  #sxsw.
# 7272  #sxsw!
# 7273  #bankinnovate #sxsw
#
# [7273 rows x 6 columns]

# %%
cdf['hashtags'].head()
# Out:
# 0    #sxswnui #sxsw #apple
# 1    #googledoodle #sxsw
# 2    #sxsw,
# 3    #sxsw #fuckit #illmakeitwork
# 4    #sxsw
# Name: hashtags, dtype: object

# %%
df_train['hashtags'].value_counts().head(10).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hashtags'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f50b861e03d3> in <module>
# ----> 1 df_train['hashtags'].value_counts().head(10).plot(kind='bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hashtags'

# %%
# hash = df_train['tweet'].str.extractall(r"(#\S+)")

# %%
# hash

# %%
cdf.head()
# Out:
#    tweet_id  \
# 0  1701
# 1  1851
# 2  2689
# 3  4525
# 4  3604
#
#                                                                                                                                              tweet  \
# 0  #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1  learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2  one of the most in-your-face ex. of stealing the show in yrs rt @mention &quot;at #sxsw, apple schools the mkt experts&quot;  {link}
# 3  this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4  line outside the apple store in austin waiting for the new ipad #sxsw  {link}
#
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  0
# 4  1
#
#                                                                                                                                     tweet_html  \
# 0  #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1  learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw
# 2  one of the most in-your-face ex. of stealing the show in yrs rt @mention "at #sxsw, apple schools the mkt experts"  {link}
# 3  this iphone #sxsw app would b pretty awesome if it didn't crash every 10mins during extended browsing. #fuckit #illmakeitwork
# 4  line outside the apple store in austin waiting for the new ipad #sxsw  {link}
#
#                                                                                                tweet_tokens  \
# 0  sxswnui sxsw apple defining language touch different dialect becoming smaller
# 1  learning ab google doodle doodle light funny innovative exception significant occasion googledoodle sxsw
# 2  one in-your-face ex stealing show yr rt mention sxsw apple school mkt expert '' link
# 3  iphone sxsw app would b pretty awesome crash every 10mins extended browsing fuckit illmakeitwork
# 4  line outside apple store austin waiting new ipad sxsw link
#
#                        hashtags
# 0  #sxswnui #sxsw #apple
# 1  #googledoodle #sxsw
# 2  #sxsw,
# 3  #sxsw #fuckit #illmakeitwork
# 4  #sxsw

# %%
cdf.to_csv(r'C:\Users\Vardhaman\Desktop\DS\Hackathon_3\git_sentiment\data\Iter\train_clean_data.csv', index = False)

# %%
cdf.to_csv(r'C:\Users\Vardhaman\Desktop\DS\Hackathon_3\git_sentiment\data\Iter\train_clean_data.csv', index = False)

# %%
from html.parser import HTMLParser
html = HTMLParser()

# %%
cdf = df_train.copy() 
cdf.dropna(inplace=True)
cdf['tweet_html'] = cdf['tweet'].apply(lambda x: html.unescape(x))

# %%
cdf.tweet_html
# Out:
# 0       #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1       Learning ab Google doodles! All doodles should be light, funny & innovative, with exceptions for significant occasions. #GoogleDoodle #sxsw
# 2       one of the most in-your-face ex. of stealing the show in yrs RT @mention "At #SXSW, Apple schools the mkt experts"  {link}
# 3       This iPhone #SXSW app would b pretty awesome if it didn't crash every 10mins during extended browsing. #Fuckit #Illmakeitwork
# 4       Line outside the Apple store in Austin waiting for the new iPad #SXSW  {link}
#                                             ...
# 7269    @mention Google plze Tammi.  I'm in middle of #SXSW craziness and everything is soooooo busy!
# 7270    RT @mention ÷¼ Are you all set? ÷_ {link} ÷_ #edchat #musedchat #sxsw #sxswi #newTwitter
# 7271    RT @mention Aha! Found proof of lactation room, excuse me, "Mother's Room," brought to you by Google, at last year's #SXSW. {link}
# 7272    We just launched our iPad app at #SXSW! Get all the details + the first edition FREE: {link}
# 7273    The next fin serv battle is vs Apple, GOOG, Mobile operators. They have consumer loyalty and tons of cash (vs. Banks) #bankinnovate #SXSW
# Name: tweet_html, Length: 7273, dtype: object

# %%
def get_hashtags(text, handle_space=True):
    if handle_space:
        space = r"#\s+"
        text = re.sub(space, "#", str(text).lower()).strip()
    hash_tags = r"#\S+"
    return " ".join(re.findall(hash_tags, text))  
cdf['hashtags'] = cdf.tweet.apply(get_hashtags)

# %%
cdf.hashtags.value_counts()
# Out:
# #sxsw                                3367
# #sxsw.                               200
# #sxsw?                               87
# #sxsw:                               84
# #sxsw,                               73
#                                      ..
# #sxtxstate #sxsw                     1
# #sxsw #qagbû                       1
# #sxsw #bummer                        1
# #ipad2 #apple #crazyco #sxsw         1
# #apple #ipad2 #sxsw #tech #retail    1
# Name: hashtags, Length: 1800, dtype: int64

# %%
import string
from nltk.corpus import stopwords

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punct = '!"$%&\'()*+,-./:;<=>?@[\\]^_`{|}~û'

# %%
# from nltk.
hashlist = []
for word in cdf.hashtags:
          if (word not in stopwords.words('english') and 
                word not in punct): # remove punctuation
                #tweet = str(TextBlob(word).correct())                        
                    #else use the tag to lemmatize the token
                hashlist.append(word)

# %%
hashlist
# Out:
# ['#sxswnui #sxsw #apple',
#  '#googledoodle #sxsw',
#  '#sxsw,',
#  '#sxsw #fuckit #illmakeitwork',
#  '#sxsw',
#  '#technews #tech_news #apple #ipad_2 #sxsw #tablets #tech',
#  '#sxsw #ipad',
#  '#ubersocial #iphone #sxsw #mashable',
#  '#sxsw #freemusic',
#  '#sxsw',
#  '#sxsw #android #iphone #ipad',
#  '#sxsw #elevate',
#  '#sxsw #techenvy',
#  '#sxsw! #zazzlsxsw',
#  '#companies #sxsw #apps #features #hardware #ipad #iphone',
#  '#sxsw',
#  '#calyp #calyp #sxsw',
#  '#sxsw',
#  '#apple #ipad2 #technology #itunes #sxsw',
#  '#sxsw. #doubleloser',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#rise_austin, #sxsw.',
#  '#circles #sxsw',
#  '#circles #sxsw\x89û\x9d',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #startups #vc #movie #awesome',
#  '#sxsw',
#  '#apple #sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#ipad #sxsw',
#  '#ipad #sxsw',
#  '#sxsw:',
#  '#sxsw',
#  '#sxsw #deferomobile',
#  '#ipad2 #sxsw',
#  '#sxsw #apple #ipad2',
#  '#sxsw #fb',
#  '#sxsw',
#  '#android #iphone #sms #stevemartocci #sxsw',
#  '#entry #friends #house #sxsw',
#  '#sxsw',
#  '#sxsw. #sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#psych #sxsw',
#  '#recco! #sxsw',
#  '#sxsw\x89û\x9d',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#googlecircles #googleme #sxsw',
#  '#sxsw',
#  '#sxsw #13:',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#twitterpower #sxsw #imthatgood',
#  '#sxsw',
#  '#sxsw? #ipad',
#  '#sxsw',
#  '#sxsw?',
#  '#sxsw #netflixiphone',
#  '#sxsw',
#  '#ipad2 #sxsw',
#  '#google #circles, #sxsw',
#  '#bjdproductions #apple #sxsw #tech',
#  '#sxsw #iphoneography #mobilephotography',
#  '#apple #sxsw',
#  '#sxsw #ipad2',
#  '#4sq #checkins #sxsw',
#  '#sxsw',
#  '#tech #lightbox_photos #android #sxsw): #technology',
#  '#sxsw #sxswi',
#  '#ipad2 #sxsw',
#  '#sxsw',
#  '#libya #sxsw',
#  '#social #google #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw?',
#  '#ubersocial #iphone #sxsw #mashable',
#  '#circles #sxsw',
#  '#ipad2 #sxsw',
#  '#infektd #sxsw #necro',
#  '#gsdm #google #sxsw',
#  '#sxsw',
#  '#sxsw #fmsignal #google',
#  '#sxsw #enchantment:',
#  '#sxsw #sxswpass',
#  '#lovemusicapi #sxsw',
#  '#sxsw',
#  '#sxsw #9to5',
#  '#sxsw #touchingstories',
#  '#sxsw',
#  '#ipad #sxsw..',
#  '#sxsw',
#  '#sxswinfo #sxsw',
#  '#sxsw',
#  '#gsdm #google #sxsw',
#  '#sxsw',
#  '##sxsw. #googlecircles',
#  '#sxsw',
#  '#sxsw:',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#tech #sxsw',
#  '#sxsw!',
#  '#sxsw',
#  '#sxsw',
#  '#apple #sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #industrialdesign',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #fail #owllove',
#  '#sxsw',
#  '#ipad #art #ipad #sxsw',
#  '#sxsw #ipad2',
#  '#virtualwallet #sxsw #paypal #apple',
#  '#sxsw.',
#  '#sxsw #ipad',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #socialmedia',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxflip #sxsw',
#  '#gsdm #sxsw',
#  '#google #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#apple #hp #sxsw; #austin #atx #austinbusiness',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw!',
#  '#sxsw #mobile491',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #shared',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#apple #sxsw #ipad2',
#  '#usguys #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw!',
#  '#apple #sxsw',
#  '#sxsw',
#  '#sxsw #fb',
#  '#apple #sxsw,',
#  '#@mention #launch #sxsw',
#  '#sxsw:',
#  '#seattle #sxsw',
#  '#sxsw #notatsxsw',
#  '#sxsw #social',
#  '#sxsw',
#  '#sxsw #apple #sxsw2011',
#  '#bt #sxsw #google&quot;',
#  '#sxsw',
#  '#sxsw',
#  '#google #circles #sxsw #socbiz #fb',
#  '#sxsw',
#  '#pnid #sxsw',
#  '#sxsw: #sxswi',
#  '#piday #google #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#seenocreepy #sxsw',
#  '#sxsw #fmsignal #sxswi',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw~updates',
#  '#sxsw',
#  '#sxsw',
#  '#augmentedreality #sxsw',
#  '#minimalistprogramming #marissagoogle #sxsw',
#  '#sxsw',
#  '#google #sxsw',
#  '#sxsw #fxsw',
#  '#sxsw! #saytextson!',
#  '#sxsw,',
#  '#sxsw,',
#  '#apple #sxsw',
#  '#ogilvy #sxsw',
#  '#sxsw',
#  '#sxsw #microsoft',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #socialmedia #ipad',
#  '#sxsw',
#  '#sxsw',
#  '#ipad #sxsw #cbatsxsw',
#  "#ipad2's #sxsw.",
#  '#sxsw\x89û\x9d',
#  '#enchantment #sxsw #sxswi',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #wantlet',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #apple',
#  '#sxsw: #indieauthors:',
#  '#sxsw',
#  '#sxsw',
#  '#edchat #musedchat #sxsw #sxswi #classical #newtwitter',
#  '#sxsw #startups',
#  '#sxsw',
#  '#sxsw #bestworstthingever',
#  '#discotalk #sxsw #sloanxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #gsdm',
#  '#sxsw #ipad2',
#  '#sxsw',
#  '#sxsw #ipad',
#  '#sxsw #ipad #digital',
#  '#sxsw #winning',
#  '#sxsw',
#  '#sxsw #japan',
#  '#sxsw',
#  '#google #social #circles, #tech #sxsw',
#  '#sxsw? #ipad #iphone',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#merissa #mayor #sxsw',
#  '#sxsw',
#  '#sxsw #apple #aphone #canada',
#  '#ipad #sxsw #ipad #art.',
#  '#sxsw',
#  '#sxsw',
#  '#futureofed #gsdm #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #donline',
#  '#sxsw #qagb',
#  '#ipad #sxsw #apple',
#  '#sxsw #sxswh #hcsm',
#  '#sxsw',
#  '#sxsw? #iphone',
#  '#sxsw',
#  '#sxsw?',
#  '#iphone #android #blackberry #windowsmobile #sxsw',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#winning #android #google #sxsw',
#  '#apple #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #sxsw',
#  '#sxsw\x89û\x9d',
#  '#sxsw',
#  '#sxsw',
#  '#ipad2 #austin #sxsw #apple',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxsw',
#  '#sxsw #wiiings',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw!',
#  '#smmnextgen #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#fail #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#qagb #sxsw',
#  '#blackberry #sprint #sxsw #apple',
#  '#sxsw',
#  '#theindustryparty #google #gsdm. #swsurrogates. #sxsw #notpouting',
#  '#sxsw',
#  '#loveit #sxsw #startupbus',
#  '#sxsw',
#  '#apple #sxsw',
#  '#sxsw',
#  '#browserwars #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#apple #sxsw #ipad2',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw?',
#  '#qagb #sxsw #seo',
#  '#ubersocial #iphone #sxsw #mashabl\x89û_',
#  '#japan #sxsw #twitter #iphone #socialmedia #philanthropy',
#  '#sxsw',
#  '#ubersocial #iphone #sxsw #mashable',
#  '#widfy #sxsw',
#  '#sxsw',
#  '#sxsw!',
#  '#sxsw:',
#  '#sxsw',
#  '#sxsw',
#  '#austinites #sxsw #iphone',
#  '#iphone #app #sxsw #virtualoffice',
#  '#apple #gsdm #sxsw #welivehere',
#  '#sxsw #super',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#gsdm #sxsw',
#  "#sxsw #in #newsapp #i'mconfused",
#  '#sxsw',
#  '#apple #sxsw',
#  '#nokiaconnects #sxsw',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#apple #ipad2 #sxsw',
#  '#sxsw',
#  '#free #sxsw',
#  '#sxsw? #iphone',
#  '#sxsw',
#  '#ubersocial #iphone #sxsw',
#  '#ipad #sxsw #apple',
#  '#sxsw',
#  '#sxsw #4hb #cheatday',
#  '#sxsw #sxsw4jp #archforhumanity',
#  '#google #sxsw #lxh',
#  '#sxsw',
#  '#sxsw? #groundlink',
#  '#sxsw',
#  '#sxsw #xplat',
#  '#qagb #sxsw',
#  '#doingitwrong #sxsw',
#  '#sxsw',
#  '#sxsw #ipad2?',
#  '#sxsw:',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#circles #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #ipad2',
#  '#itunes #sxsw #apple',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#socialmuse #android #appcircus #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #facebook #twitter #sxsw',
#  '#sxsw',
#  '#ipad2 #sxsw',
#  '#sxsw #sxswi',
#  '#sxsw',
#  '#sxsw',
#  '#dgtltribe #sxsw #openbeta6',
#  '#bjdproductions #apple #sxsw, #tech',
#  '#sxsw',
#  '#ipad2 #sxsw',
#  '#sxsw!',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw!! #usguys',
#  '#sxsw. #uxdes',
#  '#sxsw',
#  '#logo #sxsw',
#  '#news #barry_diller #iac #newsweek #sxsw #cyber #iphone',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswsa',
#  '#sxsw',
#  '#sxsw #apple #ipad2',
#  '#sxsw #ipad2',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#gssxsw #sxsw #sxsw2011 #sxswnl',
#  '#cnngrill. #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #ipad2',
#  '#sxsw\x89û\x9d',
#  '#vcards, #qrcode #iphone #sxsw',
#  '#domo #tonchidot #boom #sxsw',
#  '#sxsw #productive.',
#  '#ipad #sxsw #yourmom',
#  '#ihearnetwork #sxsw.',
#  '#sxsw.',
#  '#sxsw #ipad2 #sxsw2011 #apple',
#  '#sxsw #ipad2',
#  '#technology #apple #sxsw, #tech',
#  '#sxsw',
#  '#newsapps #sxsw',
#  '#gooddeed #sxsw #winning',
#  '#sxsw #csr',
#  '#sxsw #at&amp;t',
#  '#sxsw',
#  '#sxsw #ogilvy #sydney #sxsw #podcast #ausxsw',
#  '#bpm #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw?',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#ncaa #sxsw',
#  '#infektd #sxsw #necro',
#  '#discovr #sxsw!',
#  '#sxsw',
#  '#sxsw',
#  '#mullenweg #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #gsdm #sxsw',
#  '#rackspace #sxsw #top_news',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #in',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxswi #sxsw #google #circles #social',
#  '#sxsw #sxswgo',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #google',
#  '#sxsw',
#  '#sxsw',
#  '#apple #hp #sxsw; #austin #atx #austinbusiness',
#  '#periscope #sxsw.',
#  '#sxsw, #a11y2go',
#  '#techrockstar #sxsw',
#  '#sxsw',
#  '#busy #sxsw',
#  '#sxsw #google #circles',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#saysshewithoutanipad #sxsw',
#  '#sxsw',
#  '#sxsw #raidsxsw',
#  '#sxsw',
#  '#sxsw!',
#  '#sxsw #privacy',
#  '#sxsw #1',
#  '#sxsw',
#  '#sxsw #overtweeting',
#  '#sxsw',
#  '#newsapps #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#tradeshow #sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#bnet #biz #ipad2 #apple #sxsw #ipad',
#  '#sxsw',
#  '#austin, #iphone #android, #sxsw?',
#  '#googledoodle #sxsw',
#  '#popplet. #sxsw.',
#  '#sxsw. #geeksrejoice',
#  '#sxsw,',
#  '#sxsw.',
#  '#sxsw',
#  '#frood #sxsw',
#  '#sxsw #sxswpass',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw #cstejas',
#  '#sxsw!',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#winning. #ipad2 #sxsw',
#  '#hangover3, #sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #musicconnex',
#  '#google #marissameyer #clevelandsteamer. #sxsw',
#  '#google #circles. #sxsw',
#  '#sxsw',
#  '#fools #sxsw',
#  '#sxsw',
#  '#sxsw #connectedtv',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#ubersocial #iphone #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #sxsw #circles.',
#  '#sxsw',
#  '#sxsw #sxsw. #sxsw',
#  '#iphone #nes #sxsw #thestreet',
#  '#sxsw',
#  '#sxsw #toocoolforsxswanyway',
#  '#sxsw',
#  '#sxsw:',
#  '#sxsw #cnn',
#  '#sxsw',
#  '#iphone #android, #sxsw?',
#  '#itunes #ipad2 #1990style #sxsw',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw.',
#  '#sxsw #screenfuture',
#  '#iphone #eventseekr #sxsw!!',
#  '#sxsw',
#  '#app #sxsw #free',
#  '#sxsw',
#  '#beevil #sxsw',
#  '#sxsw!',
#  '#sxsw',
#  '#atx #sxsw',
#  '#google #circles #sxsw',
#  '#ipad2 #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #sxsw',
#  '#sxsw',
#  '#sxsw?',
#  '#sxsw',
#  '#sxsw #protip',
#  '#sxsw #winning',
#  '#sxsw',
#  '#sxsw #google #circles',
#  '#checkins #sxsw',
#  '#sxsw',
#  '#sxsw #fh',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #agileagency',
#  '#sxsw',
#  '#sxsw: #sxswi\x89û\x9d',
#  '#sxsw. #sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw #apple',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#marissagoogle #sxsw',
#  '#sxsw.',
#  '#sxsw:',
#  '#hbs #startuptribe #sxsw',
#  '#longform #sxsw #jmc322',
#  '#sxsw #filmfestepic',
#  '#sxsw',
#  '#sxsw,',
#  '#google #circles #fail #sxsw',
#  '#sxsw',
#  '#spiltbeer #sxsw',
#  '#sxsw',
#  '#sxsw #film',
#  '#sxsw',
#  '#socialmedia #sxsw #facebook #monopoly #integration',
#  '#sxsw #sxswfilm #sxswi #almedia',
#  '#apple #ipad2 #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #circles #social #sxsw',
#  '#google #circles, #sxsw',
#  '#sxsw #ipad2',
#  '#sxsw #apple #ipad2',
#  '#pushio #sxsw #ipad',
#  '#sxsw',
#  '#sxsw #ipad',
#  '#socialmedia #music #sxsw #ipad2 #iphone',
#  '#infektd #sxsw #cvdc',
#  "#google's #mobile #eurorscg #sxsw #sxswi",
#  '#sxsw',
#  '#sxsw #sxswdad',
#  '#itunes #austin #bbq #sxsw #sxswi',
#  '#infektd #sxsw #zlf',
#  '#sxsw',
#  '#sxsw',
#  '#technology #apple #sxsw: #tech',
#  '#sxsw',
#  '#css #sxsw',
#  '#sxsw',
#  '#sxsw #accordion #toodamnlucky',
#  '#ubersocial #iphone #sxsw',
#  '#sxsw',
#  '#hack5 #sxsw #donline',
#  '#osmpw #sxsw',
#  '#checkins #sxsw',
#  '#sxsw #ipad',
#  '#sxsw',
#  '#sxsw #ipad2',
#  '#google #google #sxsw',
#  '#sxsw #mobile',
#  '#sxsw #itunes',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw\x89û\x9d',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw?',
#  '#iphone #sxsw',
#  '#moreknowledge #sxsw #mitharvard',
#  '#sxsw.',
#  '#enchantment #sxsw',
#  '#iphone #android, #sxsw?',
#  '#agnerd #sxsw #agchat',
#  '#sxsw #sxswi',
#  '#sxsw #googlecircles',
#  '#sxsw',
#  '#ogilvy #sydney #sxsw #podcast #up, #hashtags #ausxsw',
#  '#sxsw',
#  '#newsapps #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #marissameyer #clevelandsteamer. #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#edchat #musedchat #sxsw #sxswi #classical #newtwitter',
#  '#apple #sxsw #wow',
#  '#sxsw #outbrain, #ipad, #groupme,',
#  '#sxsw',
#  '#sxsw',
#  '#free #music #sxsw',
#  '#sxsw:',
#  '#ipad2 #sxsw #popup',
#  '#sxsw',
#  '#sxsw #rgv',
#  '#ubersocial #iphone #sxsw #mashable',
#  '#sxsw',
#  '#sxsw #cnn',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #fail',
#  '#sxsw #awkward.',
#  '#circles #sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #fail',
#  '#tech #apple #sxsw, #technology',
#  '#lmndst #sxsw #startupbus',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#google #pnid #sxsw',
#  '#google #sxsw #pnid',
#  '#sxsw #protip #in',
#  '#sxsw?',
#  '#sxsw',
#  '#sxsw.',
#  '#agileagency #sxsw',
#  '#sxsw #mobile',
#  '#sxsw #apple #austin',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswi #google #tcs_dw',
#  '#sxsw',
#  '#ehteam #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw?',
#  '#platform #sxsw #gsdm',
#  '#sxsw',
#  '#100tc #sxswi #sxsw #ipad',
#  '#sxsw #numbassonfloor',
#  '#sxsw',
#  '#sxsw',
#  '#hashable #sxsw #iphone #android',
#  '#tapworthy #sxsw',
#  '#sxsw',
#  '#sxsw #qagb #raidsxsw',
#  '#netflix #sxsw',
#  '#sxsw #analog',
#  '#futuremf #sxsw',
#  '#sxsw #groupchatapps',
#  '#sxsw\x89û\x9d',
#  '#ogilvynotes #sxsw',
#  '#ipad #sxsw #weekend #battlela',
#  '#sxsw',
#  '#sxsw? #austin #lp',
#  '#facebook #google #sxsw',
#  '#sxsw',
#  '#redbullbpm #sxsw',
#  '#tapworthy #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#tapworthy #winning #tigerblood #sxsw',
#  '#sxsw',
#  '#sxsw,',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#circles #sxsw',
#  '#google #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #ignitesxsw',
#  '#sxsw',
#  '#circles #sxswi #sxsw',
#  '#sxsw #ipad2',
#  '#googledoodle #sxsw',
#  '#google #digital #mobile #sxsw',
#  '#sxsw #mcommerce',
#  '#sxsw',
#  '#sxsw',
#  '#apple #sxsw #rji',
#  '#sxsw',
#  '#sxsw #youkidshavefun',
#  '#sxsw',
#  '#sxsw! #groundlink',
#  '#sxsw #awesometiming',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#google #sxsw #sxsw2011',
#  '#google #savebrands #sxsw',
#  '#sxsw.',
#  '#sxsw!',
#  '#circles #sxsw',
#  '#apple #sxsw',
#  '#sxsw,',
#  '#pvhouse? #win #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#filmaster #iphone #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #apple #marketing',
#  '#sxsw.',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw. #ipad2',
#  '#sxsw #sxswi #sxsh #sxswh #hcsm #slp',
#  '#crushit #sxsw #tye',
#  '#sxsw #nokiaconnects',
#  '#sxsw #prepared #iloveasurprise',
#  '#sxsw #iphone #istoned #tweetaholic #tech #tweetanonymous #addict',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw #qagb',
#  '#sxsw',
#  '#techi #pepsicostage, #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw.',
#  '#sxsw #wssxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#android #sxsw #app',
#  '#li #fb #sxsw',
#  '#sxsw',
#  '#sxsw? #sxswi #ipad',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#hollergram #sxsw',
#  '#sxsw!',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #conservebatterylife #peace',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw,',
#  '#sxsw',
#  '#mashhash #sxsw',
#  '#bnet #biz #ipad2 #apple #sxsw #ipad #tablet #xoom #tech #laptop #pics #sale',
#  '#sxsw',
#  '#sxsw #sxswi',
#  '#sxsw',
#  '#papasangre #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw\x89û\x9d',
#  '#socialfuel #sxsw',
#  '#sxsw',
#  '#hootsuite #sxsw',
#  '#sxsw',
#  '#itunes #sxsw',
#  '#sxsw',
#  '#ipad #sxsw!',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw, #justsaying',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw!',
#  '#sxsw',
#  '#newsapps #sxsw',
#  '#sxsw,',
#  '#sxsw #gswsxsw',
#  '#google #mayer #sxsw',
#  '#sxsw',
#  '#sxsw. #sxsw&quot;',
#  '#sxsw',
#  '#sxsw',
#  '#barrydiller #sxsw #pnid',
#  '#technews #tech_news #apple #ipad_2 #rance_wilemon #sxsw #tech',
#  '#sxsw,',
#  '#apple #marissagoogle #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#911tweets #sxsw. #umassjour',
#  '#sxsw #gsdm #sxswmobileapps',
#  '#sxsw! #zazzlsxsw',
#  '#drunkwalrus. #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw:',
#  '#sxsw?',
#  '#sxsw',
#  '#music? #sxsw #itunes.',
#  '#seenocreepy #sxsw #pnid',
#  '#sxsw',
#  '#sxsw',
#  '#ipad #apple #sxsw #sleepy',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw. #!!',
#  '#sxsw',
#  '#sxsw',
#  '#google #sxsw. #technews',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #dokobots #iphone',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #web3 #saatchiny',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #artallaround',
#  '#ipad #sxsw #tapworthy #gsdm',
#  '#sxsw #flashmob #kickball #6thstreet',
#  '#sxsw',
#  '#google #circles #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #sxswedu',
#  '#sxsw',
#  '#sxsw #nptech',
#  '#sxsw',
#  '#sxsw #ipad2time',
#  '#sxsw',
#  '#apple #ipad2 #sxsw #fb',
#  '#sxsw',
#  '#sxsw #sxswsa #apple #ipad2 #austin #texas',
#  '#fmsignal #sxsw',
#  '#sxsw #iphone #iosdevices',
#  '#aapl #sxsw #in',
#  '#agnerd #sxsw',
#  '#sxsw',
#  '#sxsw:',
#  '#sxsw, #eatshopaustinapp',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #cnet',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #il',
#  '#sxsw #apple',
#  '#sxsw #ipad2. #apple #news #sxswi',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #bettercloud',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#ipad #apps #media #sxsw',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #devops:',
#  '#sxsw',
#  '#sxsw',
#  '#sxsw #looseorganizations',
#  '#sxsw #wedig',
#  '#android #sxsw',
#  '#sxsw',
#  '#sxsw',
#  "#android's #smartphones #technology #mobile #sxsw #sxswi",
#  '#sxsw #touchingstories',
#  '#sxsw #mobile',
#  '#sxsw',
#  '#sxsw. #tapworthy',
#  '#sxsw',
#  '#fb #sxsw',
#  '#sxsw',
#  '#sxsw #bemyneighbor',
#  ...]

# %%
cleanhashlist = []
no_punct = ""
for word in hashlist:
    if word not in punct:
        cleanhashlist.append(no_punct + word)

# display the unpunctuated string
hash_df = pd.DataFrame(cleanhashlist)
hash_df.columns = ['hashes']
 
# clean_hash = 
clean_hash = hash_df['hashes'].str.replace('[{}]'.format(punct), '').str.split()

# %%
clean_hash_1 = []
def reemovNestings(l): 
    for i in l: 
        if type(i) == list: 
            reemovNestings(i) 
        else: 
            clean_hash_1.append(i)
reemovNestings(clean_hash)

# %%
hash_count_df = pd.DataFrame(pd.Series(clean_hash_1).value_counts())

# %%
hash_count_df.columns = ['Frequency']

# %%
sns.barplot(x=hash_count_df[:10].index,y=hash_count_df['Frequency'][:10])
plt.xticks(rotation=90)
plt.xlabel('Most Popular Hashtags')
plt.ylabel('Frequency')
plt.title('Hashtags')
# Out:
# Text(0.5, 1.0, 'Hashtags')

# %%
# Out:
# Index(['#sxsw', '#apple', '#sxswi', '#google', '#ipad2', '#iphone', '#ipad',
#        '#android', '#austin', '#circles', '#tech', '#ubersocial', '#gsdm',
#        '#japan', '#tapworthy'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-3536571a9bc3> in <module>
# ----> 1 train
#
# NameError: name 'train' is not defined

# %%
print("Before using HTML Parser :")
print(' ')
print(cdf.iloc[1,1])
print(' ')
print('**********************************************************')
print(' ')
print('After using HTML Parser :')
print(' ')
print(cdf.iloc[1,3])
# Out:
# Before using HTML Parser :
#
# learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
#
# **********************************************************
#
# After using HTML Parser :
#
# learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw

# %% [markdown]
# **Before using HTML Parser :**
#
# learning ab google doodles! all doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #googledoodle #sxsw
#
# **********************************************************
#
# **After using HTML Parser :**
#
# learning ab google doodles! all doodles should be light, funny & innovative, with exceptions for significant occasions. #googledoodle #sxsw
